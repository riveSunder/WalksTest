# %%
temp = input("enter the url")

# %%
import skimage 
import skimage.io as sio

sio.imsave("temp.png")

# %%
import os
os.system(f"wget {temp} -O temp.png")

# %% [markdown]
# <img src="temp.png">
